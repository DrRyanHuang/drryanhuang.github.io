# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
import geopy
geopy.geocoders.options.default_user_agent = "my-application"
# Out:
# Requirement already up-to-date: getorg in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (0.3.1)
# Requirement already satisfied, skipping upgrade: pygithub in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from getorg) (1.54.1)
# Requirement already satisfied, skipping upgrade: geopy in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from getorg) (2.1.0)
# Requirement already satisfied, skipping upgrade: retrying in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from getorg) (1.3.3)
# Requirement already satisfied, skipping upgrade: deprecated in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from pygithub->getorg) (1.2.10)
# Requirement already satisfied, skipping upgrade: pyjwt<2.0 in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from pygithub->getorg) (1.7.1)
# Requirement already satisfied, skipping upgrade: requests>=2.14.0 in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from pygithub->getorg) (2.25.0)
# Requirement already satisfied, skipping upgrade: geographiclib<2,>=1.49 in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from geopy->getorg) (1.50)
# Requirement already satisfied, skipping upgrade: six>=1.7.0 in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from retrying->getorg) (1.15.0)
# Requirement already satisfied, skipping upgrade: wrapt<2,>=1.10 in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from deprecated->pygithub->getorg) (1.12.1)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from requests>=2.14.0->pygithub->getorg) (1.26.2)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from requests>=2.14.0->pygithub->getorg) (2020.6.20)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from requests>=2.14.0->pygithub->getorg) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /home/ryan/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages (from requests>=2.14.0->pygithub->getorg) (3.0.4)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-6feaf8288492> in <module>
#       4 import geopy
#       5 geopy.geocoders.options.default_user_agent = "my-application"
# ----> 6 import geopy.Nominatim as Nominatim
#
# ModuleNotFoundError: No module named 'geopy.Nominatim'

# %%
g = glob.glob("*.md")

# %%
geocoder = geopy.Nominatim()
location_dict = {}
location = ""
permalink = ""
title = ""
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# <ipython-input-8-cd980ae579e7> in <module>
# ----> 1 geocoder = Nominatim()
#       2 location_dict = {}
#       3 location = ""
#       4 permalink = ""
#       5 title = ""
#
# ~/Public/miniconda3/envs/open-mmlab/lib/python3.7/site-packages/geopy/geocoders/nominatim.py in __init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     112                 'overriding the default `user_agent`: '
#     113                 '`geopy.geocoders.options.default_user_agent = "my-application"`.'
# --> 114                 % self.headers['User-Agent']
#     115             )
#     116
#
# ConfigurationError: Using Nominatim with default or sample `user_agent` "my-application" is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`.

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# Berkeley CA, USA
#  Berkeley, Alameda County, California, United States of America
# Los Angeles, CA
#  LA, Los Angeles County, California, United States of America
# London, UK
#  London, Greater London, England, UK
# San Francisco, California
#  SF, California, United States of America

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
